# %%
# نصب کتابخانه‌های مورد نیاز
# !pip install roboflow ultralytics opencv-python-headless

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="oVBAHtT6bMrjxxiiiRh7")
project = rf.workspace("rl-tkpnx").project("low-level")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to low-level-1 in yolov8:: 100%|██████████| 186/186 [00:00<00:00, 9673.52it/s]

# %%
# ✅ آپلود فایل low level.zip
from google.colab import files
uploaded = files.upload()

# ✅ استخراج فایل zip
import zipfile
import os

zip_filename = "low level.v1i.yolov8.zip"  # اسم دقیق فایل زیپ آپلود شده
extract_path = "/content/low_level_dataset"

with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ فایل با موفقیت از حالت فشرده خارج شد.")

# ✅ تنظیم مسیرهای داینامیک
data_yaml_path = os.path.join(extract_path, "data.yaml")
train_path = os.path.join(extract_path, "train")
val_path = os.path.join(extract_path, "valid")

# ✅ بررسی وجود پوشه‌ها
for path in [train_path, val_path]:
    if not os.path.exists(path):
        raise FileNotFoundError(f"❌ پوشه {path} یافت نشد! لطفاً فایل زیپ را بررسی کنید.")
if not os.path.exists(data_yaml_path):
    raise FileNotFoundError("❌ فایل data.yaml یافت نشد! لطفاً فایل زیپ را بررسی کنید.")

print("✅ مسیرهای دیتاست به درستی شناسایی شدند.")

# ✅ آموزش YOLOv8 با استفاده از دیتاست
from ultralytics import YOLO

model = YOLO("yolov8s-seg.pt")  # می‌تونی مدل رو به دلخواه تغییر بدی مثل yolov8m یا yolov8l
results_train = model.train(data=data_yaml_path, epochs=120, imgsz=(700, 130), batch=8, device="cuda")  # برای GPU

# ✅ ذخیره مدل
model.save("/content/trained_model.pt")
print("✅ مدل با موفقیت ذخیره شد.")
# Out:
# ...
#      <input type="file" id="files-ce4b2025-55b5-4b02-ab68-99532c7fca76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce4b2025-55b5-4b02-ab68-99532c7fca76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
